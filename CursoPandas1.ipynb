# %% [markdown]
# <a href="https://colab.research.google.com/github/TAGARA-TECH/Pandas-E_S-trabajando-con-diferentes-formatos-de-archivo/blob/main/CursoPandas1.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # **Curso Pandas E/S trabajando con diferentes clases de archivos**

# %% [markdown]
# ## **Aula 1 - Leyendo archivos CSV**

# %%
import pandas as pd

# %%
datos = pd.read_csv('superstore_data.csv')

# %%
datos.head()
# Out:
#       Id  Year_Birth   Education Marital_Status   Income  Kidhome  Teenhome  \
# 0   1826        1970  Graduation       Divorced  84835.0        0         0
# 1      1        1961  Graduation         Single  57091.0        0         0
# 2  10476        1958  Graduation        Married  67267.0        0         1
# 3   1386        1967  Graduation       Together  32474.0        1         1
# 4   5371        1989  Graduation         Single  21474.0        1         0
#
#   Dt_Customer  Recency  MntWines  ...  MntFishProducts  MntSweetProducts  \
# 0   6/16/2014        0       189  ...              111               189
# 1   6/15/2014        0       464  ...                7                 0
# 2   5/13/2014        0       134  ...               15                 2
# 3   11/5/2014        0        10  ...                0                 0
# 4    8/4/2014        0         6  ...               11                 0
#
# ...

# %%
datos_punto_coma = pd.read_csv('superstore_data_punto_coma.csv', sep=';')

# %%
datos_punto_coma.head()
# Out:
#       Id  Year_Birth   Education Marital_Status   Income  Kidhome  Teenhome  \
# 0   1826        1970  Graduation       Divorced  84835.0        0         0
# 1      1        1961  Graduation         Single  57091.0        0         0
# 2  10476        1958  Graduation        Married  67267.0        0         1
# 3   1386        1967  Graduation       Together  32474.0        1         1
# 4   5371        1989  Graduation         Single  21474.0        1         0
#
#   Dt_Customer  Recency  MntWines  ...  MntFishProducts  MntSweetProducts  \
# 0   6/16/2014        0       189  ...              111               189
# 1   6/15/2014        0       464  ...                7                 0
# 2   5/13/2014        0       134  ...               15                 2
# 3   11/5/2014        0        10  ...                0                 0
# 4    8/4/2014        0         6  ...               11                 0
#
# ...

# %% [markdown]
# ### **Importando archivos CSV**

# %% [markdown]
# ## **Para saber más: error de codificación - ¿cómo solucionarlo?**

# %%
import chardet

# %%
with open('superstore_data.csv', 'rb') as file:
    print(chardet.detect(file.read()))
# Out:
# {'encoding': 'ascii', 'confidence': 1.0, 'language': ''}

# %%
df = pd.read_csv('superstore_data.csv', encoding='ascii')

# %%
df.head()
# Out:
#       Id  Year_Birth   Education Marital_Status   Income  Kidhome  Teenhome  \
# 0   1826        1970  Graduation       Divorced  84835.0        0         0
# 1      1        1961  Graduation         Single  57091.0        0         0
# 2  10476        1958  Graduation        Married  67267.0        0         1
# 3   1386        1967  Graduation       Together  32474.0        1         1
# 4   5371        1989  Graduation         Single  21474.0        1         0
#
#   Dt_Customer  Recency  MntWines  ...  MntFishProducts  MntSweetProducts  \
# 0   6/16/2014        0       189  ...              111               189
# 1   6/15/2014        0       464  ...                7                 0
# 2   5/13/2014        0       134  ...               15                 2
# 3   11/5/2014        0        10  ...                0                 0
# 4    8/4/2014        0         6  ...               11                 0
#
# ...

# %% [markdown]
# ## **Documentacion**
# https://pandas.pydata.org/docs/reference/api/pandas.read_csv.html
#
# https://pandas.pydata.org/pandas-docs/version/2.2.0/reference/api/pandas.read_csv.html

# %%
datos_primeras_lineas = pd.read_csv('superstore_data.csv', nrows=10)
datos_primeras_lineas
# Out:
#       Id  Year_Birth   Education Marital_Status  Income  Kidhome  Teenhome  \
# 0   1826        1970  Graduation       Divorced   84835        0         0
# 1      1        1961  Graduation         Single   57091        0         0
# 2  10476        1958  Graduation        Married   67267        0         1
# 3   1386        1967  Graduation       Together   32474        1         1
# 4   5371        1989  Graduation         Single   21474        1         0
# 5   7348        1958         PhD         Single   71691        0         0
# 6   4073        1954    2n Cycle        Married   63564        0         0
# 7   1991        1967  Graduation       Together   44931        0         1
# 8   4047        1954         PhD        Married   65324        0         1
# 9   9477        1954         PhD        Married   65324        0         1
#
#   Dt_Customer  Recency  MntWines  ...  MntFishProducts  MntSweetProducts  \
# ...

# %%
datos_seleccion_columnas = pd.read_csv('superstore_data.csv', usecols=['Id', 'Year_Birth', 'Income'])
datos_seleccion_columnas
# Out:
#          Id  Year_Birth   Income
# 0      1826        1970  84835.0
# 1         1        1961  57091.0
# 2     10476        1958  67267.0
# 3      1386        1967  32474.0
# 4      5371        1989  21474.0
# ...     ...         ...      ...
# 2235  10142        1976  66476.0
# 2236   5263        1977  31056.0
# 2237     22        1976  46310.0
# 2238    528        1978  65819.0
# 2239   4070        1969  94871.0
#
# [2240 rows x 3 columns]

# %%
datos_seleccion_columnas = pd.read_csv('superstore_data.csv', usecols=[0, 1, 4])
datos_seleccion_columnas
# Out:
#          Id  Year_Birth   Income
# 0      1826        1970  84835.0
# 1         1        1961  57091.0
# 2     10476        1958  67267.0
# 3      1386        1967  32474.0
# 4      5371        1989  21474.0
# ...     ...         ...      ...
# 2235  10142        1976  66476.0
# 2236   5263        1977  31056.0
# 2237     22        1976  46310.0
# 2238    528        1978  65819.0
# 2239   4070        1969  94871.0
#
# [2240 rows x 3 columns]

# %% [markdown]
# ## **Escribiendo archivos CSV**
# Documentacion: https://pandas.pydata.org/docs/reference/api/pandas.DataFrame.to_csv.html

# %%
datos_seleccion_columnas.to_csv('clientes_mercado.csv')

# %%
clientes_mercado = pd.read_csv('clientes_mercado.csv')
clientes_mercado
# Out:
#       Unnamed: 0     Id  Year_Birth   Income
# 0              0   1826        1970  84835.0
# 1              1      1        1961  57091.0
# 2              2  10476        1958  67267.0
# 3              3   1386        1967  32474.0
# 4              4   5371        1989  21474.0
# ...          ...    ...         ...      ...
# 2235        2235  10142        1976  66476.0
# 2236        2236   5263        1977  31056.0
# 2237        2237     22        1976  46310.0
# 2238        2238    528        1978  65819.0
# 2239        2239   4070        1969  94871.0
#
# [2240 rows x 4 columns]

# %%
datos_seleccion_columnas.to_csv('datos_mercado.csv', index=False)

# %%
datos_mercados = pd.read_csv('datos_mercado.csv')
datos_mercados
# Out:
#          Id  Year_Birth   Income
# 0      1826        1970  84835.0
# 1         1        1961  57091.0
# 2     10476        1958  67267.0
# 3      1386        1967  32474.0
# 4      5371        1989  21474.0
# ...     ...         ...      ...
# 2235  10142        1976  66476.0
# 2236   5263        1977  31056.0
# 2237     22        1976  46310.0
# 2238    528        1978  65819.0
# 2239   4070        1969  94871.0
#
# [2240 rows x 3 columns]

# %% [markdown]
# ### **Ejercicios**
# consejos:
#
# Asegúrese de que el archivo CSV esté separado por una coma o punto y coma.
# La codificación del archivo es ISO-8859-1.
# Las primeras tres líneas del archivo se pueden ignorar, ya que el encabezado sólo comienza en la cuarta línea.
# Las últimas 9 líneas también se pueden ignorar, ya que son sólo información sobre dónde se tomaron los datos.
# Para eliminar las últimas líneas es necesario agregar el parámetro engine='python'.
#
# 1-encoding='ISO-8859-1': tipo de codificación de caracteres del archivo. En este caso, es la codificación ISO-8859-1 la que es común en los archivos en idioma portugués.
#
# 2-sep=';': separador de los valores del archivo. En este caso, es el punto y coma (;).
#
# 3-skiprows=3: indica que las primeras tres líneas del archivo deben ignorarse ya que no contienen datos relevantes.
#
# 4-skipfooter=9: Indica que las últimas nueve líneas del archivo deben ignorarse ya que no contienen datos relevantes.
#
# 5-engine='python': el motor utilizado para leer el archivo es Python. Esto es necesario cuando se utiliza el parámetro skipfooter, ya que el motor predeterminado no admite esta opción.

# %%
url = 'datos_sus.csv'

# %%
datos = pd.read_csv(url, encoding='ISO-8859-1', sep=';', skiprows=3, skipfooter = 9, engine='python')

# %%
datos

# %%
with open('datos_sus.csv', 'rb') as file:
    print(chardet.detect(file.read()))
# Out:
# {'encoding': 'ISO-8859-1', 'confidence': 0.73, 'language': ''}

# %% [markdown]
# ## **Aula 2 - Importando archivos Excel**
